# %% [markdown]
# Players dataset creation
#
# The Fantacalcio players list is manually downloaded from https://www.fantacalcio.it/quotazioni-fantacalcio
#
# Here, the players database is generated, by merging the Fantacalcio list to stats downloaded from http://fbref.com

# %%
import pandas as pd

# %% [markdown]
# Load fbref data for outfield players and goalkeepers.
#
# Generate fbref player list, adding player surname (with special characters replaced to normal ones)

# %%
rcsv = pd.read_csv('fbref_data/outfield_players.csv')   
outfield_players = pd.DataFrame(rcsv)

rcsv = pd.read_csv('fbref_data/keepers_players.csv')   
keeper_players = pd.DataFrame(rcsv)

# %%
players = pd.concat(   [ outfield_players[['player', 'team']], keeper_players[['player', 'team']] ], axis = 0, ignore_index = True)

keepers_ID = len(outfield_players)

players
# Out:
#                     player        team
# 0         Francesco Acerbi       Inter
# 1              Yacine Adli       Milan
# 2         Michel Aebischer     Bologna
# 3            Lucien Agoume       Inter
# 4               Marley Aké     Udinese
# ..                     ...         ...
# 530  Alessandro Sorrentino       Monza
# 531       Marco Sportiello       Milan
# 532      Wojciech Szczęsny    Juventus
# 533     Pietro Terracciano  Fiorentina
# 534         Stefano Turati   Frosinone
#
# [535 rows x 2 columns]

# %%
import unicodedata

def normalize_name(input_str):
    nfkd_form = unicodedata.normalize('NFKD', input_str)
    only_ascii = nfkd_form.encode('ASCII', 'ignore')
    return only_ascii.decode('utf-8')

# %%
players['surname'] = players['player']
players['initial'] = players['player']

for i in range(players.shape[0]):
    players['surname'][i] = players['surname'][i].split(' ')[-1]
    players['surname'][i] = normalize_name(players['surname'][i]).replace('\'', '')
    
    
    players['initial'][i] = players['player'][i][0]

# %%
print(players[['player', 'surname']].to_string())
# Out:
#                          player           surname
# 0              Francesco Acerbi            Acerbi
# 1                   Yacine Adli              Adli
# 2              Michel Aebischer         Aebischer
# 3                 Lucien Agoume            Agoume
# 4                    Marley Aké               Ake
# 5        Jean-Daniel Akpa-Akpro        Akpa-Akpro
# 6                  Luis Alberto           Alberto
# 7               Pontus Almqvist          Almqvist
# 8              Lorenzo Amatucci          Amatucci
# 9                  Bruno Amione            Amione
# 10              Felipe Anderson          Anderson
# 11                Houssem Aouar             Aouar
# 12             Marko Arnautović        Arnautovic
# 13             Kristjan Asllani           Asllani
# 14              Tommaso Augello           Augello
# 15           Yann Aurel Bisseck           Bisseck
# 16                Sardar Azmoun            Azmoun
# 17                   Paulo Azzi              Azzi
# 18           Oussama El Azzouzi           Azzouzi
# 19                 Milan Badelj            Badelj
# 20                   Jaime Báez              Baez
# 21                Nedim Bajrami           Bajrami
# 22               Mitchel Bakker            Bakker
# 23             Tommaso Baldanzi          Baldanzi
# 24                 Lameck Banda             Banda
# 25                  Mattia Bani              Bani
# 26                Antonín Barák             Barak
# 27               Nicolò Barella           Barella
# 28             Enzo Barrenechea       Barrenechea
# 29            Davide Bartesaghi        Bartesaghi
# 30         Federico Baschirotto       Baschirotto
# 31           Alessandro Bastoni           Bastoni
# 32               Simone Bastoni           Bastoni
# 33              Raoul Bellanova         Bellanova
# 34               Andrea Belotti           Belotti
# 35                Lucas Beltrán           Beltran
# 36              Ismaël Bennacer          Bennacer
# 37             Domenico Berardi           Berardi
# 38          Bartosz Bereszyński       Bereszynski
# 39                Etrit Berisha           Berisha
# 40    Victor Bernth Kristiansen       Kristiansen
# 41                         Beto              Beto
# 42                  Sam Beukema           Beukema
# 43                   Jaka Bijol             Bijol
# 44            Cristiano Biraghi           Biraghi
# 45              Davide Biraschi          Biraschi
# 46           Samuele Birindelli        Birindelli
# 47                  Alexis Blin              Blin
# 48                 Emil Bohinen           Bohinen
# 49                Daniel Boloca            Boloca
# 50          Giacomo Bonaventura       Bonaventura
# 51           Federico Bonazzoli         Bonazzoli
# 52                 Warren Bondo             Bondo
# 53            Giovanni Bonfanti          Bonfanti
# 54               Kevin Bonifazi          Bonifazi
# 55             Gennaro Borrelli          Borrelli
# 56                 Erik Botheim           Botheim
# 57               Mehdi Bourabia          Bourabia
# 58                 Edoardo Bove              Bove
# 59             Domagoj Bradarić          Bradaric
# 60                Josip Brekalo           Brekalo
# 61               Gleison Bremer            Bremer
# 62            Marco Brescianini       Brescianini
# 63                  Dylan Bronn             Bronn
# 64        Alessandro Buongiorno        Buongiorno
# 65        Rareș-Cătălin Burnete           Burnete
# 66                   Juan Cabal             Cabal
# 67                Jovane Cabral            Cabral
# 68              Liberato Cacace            Cacace
# 69                 Jens Cajuste           Cajuste
# 70              Davide Calabria          Calabria
# 71           Riccardo Calafiori         Calafiori
# 72               Luca Caldirola         Caldirola
# 73             Hakan Çalhanoğlu        Calhanoglu
# 74            Francesco Camarda           Camarda
# 75             Nicolò Cambiaghi         Cambiaghi
# 76              Andrea Cambiaso          Cambiaso
# 77           Matteo Cancellieri       Cancellieri
# 78             Antonio Candreva          Candreva
# 79                Luigi Canotto           Canotto
# 80             Gianluca Caprari           Caprari
# 81                 Elia Caprile           Caprile
# 82             Francesco Caputo            Caputo
# 83               Andrea Carboni           Carboni
# 84             Valentin Carboni           Carboni
# 85                       Carlos            Carlos
# 86            Marco Carnesecchi       Carnesecchi
# 87                Nicolò Casale            Casale
# 88                Giuseppe Caso              Caso
# 89         Valentín Castellanos       Castellanos
# 90              Samu Castillejo        Castillejo
# 91               Danilo Cataldi           Cataldi
# 92                   Emil Ceide             Ceide
# 93                   Zeki Çelik             Celik
# 94           Michele Cerofolini        Cerofolini
# 95               Walid Cheddira          Cheddira
# 96              Federico Chiesa            Chiesa
# 97           Oliver Christensen       Christensen
# 98             Samuel Chukwueze         Chukwueze
# 99              Patrick Ciurria           Ciurria
# 100             Lorenzo Colombo           Colombo
# 101              Andrea Colpani           Colpani
# 102              Pietro Comuzzo           Comuzzo
# 103             Andrea Consigli          Consigli
# 104               Diego Coppola           Coppola
# 105             Tommaso Corazza           Corazza
# 106             Jeppe Corfitzen         Corfitzen
# 107               Benoît Costil            Costil
# 108           Lassana Coulibaly         Coulibaly
# 109           Mamadou Coulibaly         Coulibaly
# 110              Alessio Cragno            Cragno
# 111             Bryan Cristante         Cristante
# 112                   Juan Cruz              Cruz
# 113               Juan Cuadrado          Cuadrado
# 114                 Marvin Cuni              Cuni
# 115           Danilo D'Ambrosio         DAmbrosio
# 116            Flavius Daniliuc          Daniliuc
# 117                      Danilo            Danilo
# 118              Matteo Darmian           Darmian
# 119            Paweł Dawidowicz        Dawidowicz
# 120        Charles De Ketelaere         Ketelaere
# 121        Lorenzo De Silvestri         Silvestri
# 122              Koni De Winter            Winter
# 123             Grégoire Defrel            Defrel
# 124           Alessandro Deiola            Deiola
# 125               Mattia Destro            Destro
# 126       Federico Di Francesco         Francesco
# 127         Michele Di Gregorio          Gregorio
# 128         Giovanni Di Lorenzo           Lorenzo
# 129         Alessandro Di Pardo             Pardo
# 130                 Boulaye Dia               Dia
# 131            Federico Dimarco           Dimarco
# 132                Koffi Djidji            Djidji
# 133              Berat Djimsiti          Djimsiti
# 134                        Dodô              Dodo
# 135                   Josh Doig              Doig
# 136           Nicolás Domínguez         Dominguez
# 137               Giulio Donati            Donati
# 138               Patrick Dorgu             Dorgu
# 139             Alberto Dossena           Dossena
# 140               Radu Drăgușin          Dragusin
# 141                 Ondrej Duda              Duda
# 142             Denzel Dumfries          Dumfries
# 143               Alfred Duncan            Duncan
# 144                Paulo Dybala            Dybala
# 145               Festy Ebosele           Ebosele
# 146                 Enzo Ebosse            Ebosse
# 147              Tyronne Ebuehi            Ebuehi
# 148                     Éderson           Ederson
# 149           Kingsley Ehizibue          Ehizibue
# 150              Emmanuel Ekong             Ekong
# 151                Caleb Ekuban            Ekuban
# 152                  Elif Elmas             Elmas
# 153                Martin Erlic             Erlic
# 154            Giovanni Fabbian           Fabbian
# 155              Nicolò Fagioli           Fagioli
# 156           Wladimiro Falcone           Falcone
# 157              Davide Faraoni           Faraoni
# 158              Federico Fazio             Fazio
# 159              Jacopo Fazzini           Fazzini
# 160              Lewis Ferguson          Ferguson
# 161               João Ferreira          Ferreira
# 162                 Seydou Fini              Fini
# 163         Alessandro Florenzi          Florenzi
# 164          Michael Folorunsho        Folorunsho
# 165             Davide Frattesi          Frattesi
# 166             Morten Frendrup          Frendrup
# 167                Remo Freuler           Freuler
# 168            Gianluca Gaetano           Gaetano
# 169         Roberto Gagliardini       Gagliardini
# 170       Pablo Galdames Millán            Millan
# 171              Antonino Gallo             Gallo
# 172              Luca Garritano         Garritano
# 173              Federico Gatti             Gatti
# 174             Francesco Gelli             Gelli
# 175                Luca Gemello           Gemello
# 176            Valentin Gendrey           Gendrey
# 177                  Mario Gila              Gila
# 178             Gvidas Gineitis          Gineitis
# 179              Olivier Giroud            Giroud
# 180           Edoardo Goldaniga         Goldaniga
# 181           Pierluigi Gollini           Gollini
# 182                  Papu Gómez             Gomez
# 183               Joan Gonzàlez          Gonzalez
# 184            Nicolás González          Gonzalez
# 185              Alberto Grassi            Grassi
# 186            Mattéo Guendouzi         Guendouzi
# 187               Axel Guessand          Guessand
# 188          Albert Guðmundsson        Gumundsson
# 189              Emmanuel Gyasi             Gyasi
# 190             Norbert Gyömbér           Gyomber
# 191                Nicolas Haas              Haas
# 192             Ridgeciano Haps              Haps
# 193               Abdou Harroui           Harroui
# 194               Hans Hateboer          Hateboer
# 195        Pantelis Hatzidiakos       Hatzidiakos
# 196                Silvan Hefti             Hefti
# 197              Liam Henderson         Henderson
# 198            Matheus Henrique          Henrique
# 199                Thomas Henry             Henry
# 200              Theo Hernández         Hernandez
# 201                   Isak Hien              Hien
# 202                   Emil Holm              Holm
# 203               Martin Hongla            Hongla
# 204        Sydney van Hooijdonk         Hooijdonk
# 205                Dean Huijsen           Huijsen
# 206                Elseid Hysaj             Hysaj
# 207          Arijon Ibrahimović       Ibrahimovic
# 208              Jonathan Ikone             Ikone
# 209      Chukwubuikem Ikwuemesi         Ikwuemesi
# 210                   Ivan Ilić              Ilic
# 211         Samuel Iling-Junior      Iling-Junior
# 212               Ciro Immobile          Immobile
# 213              Gino Infantino         Infantino
# 214              Gustav Isaksen           Isaksen
# 215              Ardian Ismajli           Ismajli
# 216                Armando Izzo              Izzo
# 217              Filip Jagiełło            Jagieo
# 218                Jakub Jankto            Jankto
# 219                  Juan Jesus             Jesus
# 220                  Kaio Jorge             Jorge
# 221                  Luka Jović             Jovic
# 222                Mohamed Kaba              Kaba
# 223          Christian Kabasele          Kabasele
# 224               Pierre Kalulu            Kalulu
# 225               Daichi Kamada            Kamada
# 226              Hassane Kamara            Kamara
# 227                Yann Karamoh           Karamoh
# 228             Jesper Karlsson          Karlsson
# 229               Rick Karsdorp          Karsdorp
# 230           Grigoris Kastanos          Kastanos
# 231              Michael Kayode            Kayode
# 232                  Moise Kean              Kean
# 233                  Simon Kjær               Kjr
# 234               Davy Klaassen          Klaassen
# 235              Sead Kolašinac         Kolasinac
# 236            Teun Koopmeiners       Koopmeiners
# 237                Filip Kostić            Kostic
# 238            Christian Kouamé            Kouame
# 239            Viktor Kovalenko         Kovalenko
# 240           Thomas Kristensen        Kristensen
# 241             Nikola Krstović          Krstovic
# 242                 Rade Krunić            Krunic
# 243                Berkan Kutlu             Kutlu
# 244       Khvicha Kvaratskhelia     Kvaratskhelia
# 245            Giorgi Kvernadze         Kvernadze
# 246       Giorgos Kyriakopoulos     Kyriakopoulos
# 247           Gianluca Lapadula          Lapadula
# 248            Armand Lauriente         Lauriente
# 249            Valentino Lazaro            Lazaro
# 250               Darko Lazović           Lazovic
# 251              Manuel Lazzari           Lazzari
# 252                Nicola Leali             Leali
# 253                 Rafael Leão              Leao
# 254            Jesper Lindstrøm          Lindstrm
# 255               Karol Linetty           Linetty
# 256                  Pol Lirola            Lirola
# 257              Diego Llorente          Llorente
# 258           Stanislav Lobotka           Lobotka
# 259            Manuel Locatelli         Locatelli
# 260          Ruben Loftus-Cheek      Loftus-Cheek
# 261             Ademola Lookman           Lookman
# 262                Maxime Lopez             Lopez
# 263                Maxime Lopez             Lopez
# 264               Matteo Lovato            Lovato
# 265                Sandi Lovrić            Lovric
# 266               Lorenzo Lucca             Lucca
# 267                 Jhon Lucumí            Lucumi
# 268          José Luis Palomino          Palomino
# 269               Romelu Lukaku            Lukaku
# 270          Sebastiano Luperto           Luperto
# 271     Charalambos Lykogiannis       Lykogiannis
# 272             Giulio Maggiore          Maggiore
# 273         Giangiacomo Magnani           Magnani
# 274                Mike Maignan           Maignan
# 275           Antoine Makoumbou         Makoumbou
# 276              Daniel Maldini           Maldini
# 277               Youssef Maleh             Maleh
# 278          Ruslan Malinovskyi       Malinovskyi
# 279            Gianluca Mancini           Mancini
# 280               Marco Mancosu           Mancosu
# 281          Rolando Mandragora        Mandragora
# 282          Riccardo Marchizza         Marchizza
# 283          Gian Marco Ferrari           Ferrari
# 284                  Pablo Marí              Mari
# 285                 Mirko Marić             Maric
# 286                Răzvan Marin             Marin
# 287           Agustín Martegani         Martegani
# 288                Aarón Martín            Martin
# 289              Josep Martinez          Martinez
# 290            Lautaro Martínez          Martinez
# 291       Lucas Martínez Quarta            Quarta
# 292                Adam Marušić           Marusic
# 293               Alan Matturro          Matturro
# 294             Luca Mazzitelli        Mazzitelli
# 295          Pasquale Mazzocchi         Mazzocchi
# 296                Jordi Mboula            Mboula
# 297             Weston McKennie          McKennie
# 298                 Arthur Melo              Melo
# 299                  Alex Meret             Meret
# 300              Junior Messias           Messias
# 301           Nikola Milenković        Milenkovic
# 302             Arkadiusz Milik             Milik
# 303      Vanja Milinković-Savić  Milinkovic-Savic
# 304                  Yerry Mina              Mina
# 305           Aleksei Miranchuk         Miranchuk
# 306               Kevin Miranda           Miranda
# 307             Antonio Mirante           Mirante
# 308               Fabio Miretti           Miretti
# 309             Filippo Missori           Missori
# 310          Henrikh Mkhitaryan        Mkhitaryan
# 311            Ilario Monterisi         Monterisi
# 312             Lorenzo Montipò           Montipo
# 313                 Nikola Moro              Moro
# 314                   Dany Mota              Mota
# 315          Samuele Mulattieri        Mulattieri
# 316                 Luis Muriel            Muriel
# 317                 Yunus Musah             Musah
# 318                  Juan Musso             Musso
# 319               Obite N'Dicka            NDicka
# 320              Nahitan Nández            Nandez
# 321                       Natan             Natan
# 322          Michel Ndary Adopo             Adopo
# 323                   Dan Ndoye             Ndoye
# 324                Cyril Ngonge            Ngonge
# 325     Hans Nicolussi Caviglia          Caviglia
# 326               Rasmus Nissen            Nissen
# 327              Simeon Nwankwo           Nwankwo
# 328                M'Bala Nzola             Nzola
# 329                  Adam Obert             Obert
# 330                Pedro Obiang            Obiang
# 331             Guillermo Ochoa             Ochoa
# 332                 Noah Okafor            Okafor
# 333                 Caleb Okoli             Okoli
# 334             Mathías Olivera           Olivera
# 335           Gaetano Oristanio         Oristanio
# 336           Riccardo Orsolini          Orsolini
# 337              Victor Osimhen           Osimhen
# 338                  Remi Oudin             Oudin
# 339               Anthony Oyono             Oyono
# 340              Simone Pafundi           Pafundi
# 341             Riccardo Pagano            Pagano
# 342             Leandro Paredes           Paredes
# 343              Fabiano Parisi            Parisi
# 344               Mario Pašalić           Pasalic
# 345                      Patric            Patric
# 346                Rui Patrício          Patricio
# 347             Benjamin Pavard            Pavard
# 348          Leonardo Pavoletti         Pavoletti
# 349               Martín Payero            Payero
# 350             Marcus Pedersen          Pedersen
# 351                       Pedro             Pedro
# 352             Pietro Pellegri          Pellegri
# 353          Lorenzo Pellegrini        Pellegrini
# 354             Luca Pellegrini        Pellegrini
# 355            Marco Pellegrino        Pellegrino
# 356                       Pepín             Pepin
# 357               Pedro Pereira           Pereira
# 358             Roberto Pereyra           Pereyra
# 359                Nehuén Pérez             Perez
# 360                Mattia Perin             Perin
# 361             Samuele Perisan           Perisan
# 362              Matteo Pessina           Pessina
# 363              Andrea Petagna           Petagna
# 364           Giuseppe Pezzella          Pezzella
# 365             Roberto Piccoli           Piccoli
# 366             Roberto Piccoli           Piccoli
# 367            Andrea Pinamonti         Pinamonti
# 368              Lorenzo Pirola            Pirola
# 369              Tommaso Pobega            Pobega
# 370                  Paul Pogba             Pogba
# 371             Matteo Politano          Politano
# 372             Marin Pongračić         Pongracic
# 373                Stefan Posch             Posch
# 374                Matteo Prati             Prati
# 375               Ivan Provedel          Provedel
# 376           Christian Pulisic           Pulisic
# 377               George Pușcaș            Puscas
# 378              Domingos Quina             Quina
# 379               Adrien Rabiot            Rabiot
# 380                  Uroš Račić             Racic
# 381            Nemanja Radonjić          Radonjic
# 382             Boris Radunović         Radunovic
# 383                 Hamza Rafia             Rafia
# 384              Ylber Ramadani          Ramadani
# 385                Luca Ranieri           Ranieri
# 386           Filippo Ranocchia         Ranocchia
# 387           Giacomo Raspadori         Raspadori
# 388           Tijjani Reijnders         Reijnders
# 389                     Reinier           Reinier
# 390               Mateo Retegui           Retegui
# 391               Samuele Ricci             Ricci
# 392           Ricardo Rodríguez         Rodriguez
# 393           Alessio Romagnoli         Romagnoli
# 394            Simone Romagnoli         Romagnoli
# 395                 Luka Romero            Romero
# 396              Marten de Roon              Roon
# 397              Nicolò Rovella           Rovella
# 398               Amir Rrahmani          Rrahmani
# 399                        Ruan              Ruan
# 400              Daniele Rugani            Rugani
# 401              Matteo Ruggeri           Ruggeri
# 402                   Mário Rui               Rui
# 403             Stefano Sabelli           Sabelli
# 404         Alexis Saelemaekers      Saelemaekers
# 405             Lazar Samardzic         Samardzic
# 406               Junior Sambia            Sambia
# 407            Antonio Sanabria          Sanabria
# 408              Renato Sanches           Sanches
# 409              Alexis Sánchez           Sanchez
# 410                 Alex Sandro            Sandro
# 411              Nicola Sansone           Sansone
# 412           Riccardo Saponara          Saponara
# 413                Saba Sazonov           Sazonov
# 414            Giorgio Scalvini          Scalvini
# 415           Gianluca Scamacca          Scamacca
# 416                Perr Schuurs           Schuurs
# 417              Simone Scuffet           Scuffet
# 418                  Demba Seck              Seck
# 419              Vivaldo Semedo            Semedo
# 420               Stefano Sensi             Sensi
# 421                 Suat Serdar            Serdar
# 422         Stephan El Shaarawy          Shaarawy
# 423            Eldor Shomurodov        Shomurodov
# 424              Steven Shpendi           Shpendi
# 425             Marco Silvestri         Silvestri
# 426            Giovanni Simeone           Simeone
# 427          Leo Skiri Østigård           stigard
# 428            Łukasz Skorupski         Skorupski
# 429              Chris Smalling          Smalling
# 430               Ola Solbakken         Solbakken
# 431                 Yann Sommer            Sommer
# 432               Brandon Soppy             Soppy
# 433       Alessandro Sorrentino        Sorrentino
# 434             Riccardo Sottil            Sottil
# 435                Matìas Soulé             Soule
# 436         Leonardo Spinazzola        Spinazzola
# 437            Marco Sportiello        Sportiello
# 438            Trivante Stewart           Stewart
# 439           Gabriel Strefezza         Strefezza
# 440             Kevin Strootman         Strootman
# 441               Isaac Success           Success
# 442            Ibrahim Sulemana          Sulemana
# 443                Tomáš Suslov            Suslov
# 444           Wojciech Szczęsny          Szczesny
# 445        Przemysław Szymiński         Szyminski
# 446               Adrien Tameze            Tameze
# 447               Loum Tchaouna          Tchaouna
# 448          Jackson Tchatchoua        Tchatchoua
# 449         Filippo Terracciano       Terracciano
# 450          Pietro Terracciano       Terracciano
# 451             Florian Thauvin           Thauvin
# 452                Malick Thiaw             Thiaw
# 453              Morten Thorsby           Thorsby
# 454         Kristian Thorstvedt        Thorstvedt
# 455               Marcus Thuram            Thuram
# 456               Jeremy Toljan            Toljan
# 457                Rafael Tolói             Toloi
# 458               Fikayo Tomori            Tomori
# 459                 Ahmed Touba             Touba
# 460                Chaka Traorè            Traore
# 461              Stefano Turati            Turati
# 462             Kacper Urbanski          Urbanski
# 463               Johan Vásquez           Vasquez
# 464               Matías Vecino            Vecino
# 465              Lorenzo Venuti            Venuti
# 466                Simone Verdi             Verdi
# 467             Samuele Vignato           Vignato
# 468                 Matías Viña              Vina
# 469               Nicolas Viola             Viola
# 470                 Mattia Viti              Viti
# 471              Dušan Vlahović          Vlahovic
# 472               Nikola Vlašić            Vlasic
# 473        Alessandro Vogliacco         Vogliacco
# 474              Mërgim Vojvoda           Vojvoda
# 475            Cristian Volpato           Volpato
# 476              Stefan de Vrij              Vrij
# 477                      Walace            Walace
# 478       Sebastian Walukiewicz       Walukiewicz
# 479                Timothy Weah              Weah
# 480            Mateusz Wieteska          Wieteska
# 481                Kenan Yıldız              Yldz
# 482             Mattia Zaccagni          Zaccagni
# 483             Nicola Zalewski          Zalewski
# 484  Andre-Frank Zambo Anguissa          Anguissa
# 485           Alessandro Zanoli            Zanoli
# 486                Duván Zapata            Zapata
# 487                Duván Zapata            Zapata
# 488              Gabriele Zappa             Zappa
# 489           Davide Zappacosta        Zappacosta
# 490                Oier Zarraga           Zarraga
# 491               Jordan Zemura            Zemura
# 492              Alessio Zerbin            Zerbin
# 493             Piotr Zieliński         Zielinski
# 494                  David Zima              Zima
# 495              Joshua Zirkzee           Zirkzee
# 496                        Zito              Zito
# 497                Nadir Zortea            Zortea
# 498                 Milan Đurić              uric
# 499            Mateusz Łęgowski           egowski
# 500               Etrit Berisha           Berisha
# 501                Elia Caprile           Caprile
# 502           Marco Carnesecchi       Carnesecchi
# 503          Michele Cerofolini        Cerofolini
# 504          Oliver Christensen       Christensen
# 505             Andrea Consigli          Consigli
# 506               Benoît Costil            Costil
# 507              Alessio Cragno            Cragno
# 508         Michele Di Gregorio          Gregorio
# 509           Wladimiro Falcone           Falcone
# 510                Luca Gemello           Gemello
# 511           Pierluigi Gollini           Gollini
# 512                Nicola Leali             Leali
# 513                Mike Maignan           Maignan
# 514              Josep Martinez          Martinez
# 515                  Alex Meret             Meret
# 516      Vanja Milinković-Savić  Milinkovic-Savic
# 517             Antonio Mirante           Mirante
# 518             Lorenzo Montipò           Montipo
# 519                  Juan Musso             Musso
# 520             Guillermo Ochoa             Ochoa
# 521                Rui Patrício          Patricio
# 522                Mattia Perin             Perin
# 523             Samuele Perisan           Perisan
# 524               Ivan Provedel          Provedel
# 525             Boris Radunović         Radunovic
# 526              Simone Scuffet           Scuffet
# 527             Marco Silvestri         Silvestri
# 528            Łukasz Skorupski         Skorupski
# 529                 Yann Sommer            Sommer
# 530       Alessandro Sorrentino        Sorrentino
# 531            Marco Sportiello        Sportiello
# 532           Wojciech Szczęsny          Szczesny
# 533          Pietro Terracciano       Terracciano
# 534              Stefano Turati            Turati

# %% [markdown]
# Replace the surname for some specific players, according to config/name_fix.txt file.
#
# This is done for players for which the decoded fbref surname doesn't correspond to Fantacalcio list.

# %%
rcsv = pd.read_csv('config/name_fix.txt')   
name_fix = pd.DataFrame(rcsv)

for i in range(name_fix.shape[0]):
    for j in range(players.shape[0]):
        if(players['surname'][j].lower() == name_fix['FROM'][i].lower() and players['team'][j].lower() == name_fix['TEAM'][i].lower()):
            players['surname'][j] = name_fix['TO'][i]
            print(name_fix['TO'][i])

name_fix
# Out:
# Ostigard
# Augusto
# Kjaer
# Djuric
# Gudmundsson
#           FROM           TO           TEAM
# 0      stigard     Ostigard         Napoli
# 1      Min-jae          Kim         Napoli
# 2       Hjlund      Hojlund       Atalanta
# 3       Gytkjr     Gytkjaer          Monza
# 4       Carlos      Augusto          Inter
# 5         Mhle       Maehle       Atalanta
# 6          Kjr        Kjaer          Milan
# 7       uricic     Djuricic      Sampdoria
# 8         uric       Djuric  Hellas Verona
# 9       Arthur       Cabral     Fiorentina
# 10    Martinez      Alvarez       Sassuolo
# 11  Gumundsson  Gudmundsson          Genoa
# 12  Kristensen       Nissen           Roma

# %% [markdown]
# Load players from Fantacalcio list.

# %%
fc_data = pd.read_excel('fantacalcio/Quotazioni_Fantacalcio.xlsx', 'Tutti', header = 1)

fc_players = fc_data [['Id', 'R', 'Nome', 'Squadra']]

fc_players = fc_players.rename(columns = {'Id' : 'id', 'R': 'r', 'Nome' : 'name', 'Squadra' : 'team'})

fc_players['surname'] = fc_players['name']
fc_players['initial'] = fc_players['name']


for i in range(fc_players.shape[0]):
    spl = normalize_name( fc_players['name'][i].replace('\'', '') ).split(' ')
    if('.' in spl[-1]):
        fc_players.loc[i, 'surname'] = spl[-2]
        fc_players.loc[i, 'initial'] = spl[-1][0]
    else:
        fc_players.loc[i, 'surname'] = spl[-1]
        fc_players.loc[i, 'initial'] = ''
    
fc_players
# Out:
#        id  r         name         team    surname initial
# 0    2428  P       Sommer        Inter     Sommer
# 1     133  P    Skorupski      Bologna  Skorupski
# 2    5876  P  Di Gregorio        Monza   Gregorio
# 3     572  P        Meret       Napoli      Meret
# 4    2814  P     Provedel        Lazio   Provedel
# ..    ... ..          ...          ...        ...     ...
# 537  6160  A      Vivaldo      Udinese    Vivaldo
# 538  6242  A      Bidaoui    Frosinone    Bidaoui
# 539  6418  A      Burnete        Lecce    Burnete
# 540  6419  A    Corfitzen        Lecce  Corfitzen
# 541  6427  A      Stewart  Salernitana    Stewart
#
# [542 rows x 6 columns]

# %% [markdown]
# Associate players from Fantacalcio list to ID for FBref data.

# %%
fc_players['fb_ID'] = fc_players['id']

for i in range(fc_players.shape[0]):
    fc_players.loc[i, 'fb_ID']  = -1
    
    for j in range(players.shape[0]):
        if(fc_players['team'][i].lower() in players['team'][j].lower()):
            if(fc_players['surname'][i].lower() == players['surname'][j].lower()):              
                # if(fc_players['initial'][i] == '' or fc_players['initial'][i].lower() == players['initial'][j].lower()):
                if((fc_players['r'][i] == 'P') == (j >= keepers_ID)): # check wether they're a goalkeeper for both FBREF and Fantacalcio
                    fc_players.loc[i, 'fb_ID'] = j

fc_players
# Out:
#        id  r         name         team    surname initial  fb_ID     age  \
# 0    2428  P       Sommer        Inter     Sommer            529  34-354
# 1     133  P    Skorupski      Bologna  Skorupski            528  32-215
# 2    5876  P  Di Gregorio        Monza   Gregorio            508  26-132
# 3     572  P        Meret       Napoli      Meret            515  26-259
# 4    2814  P     Provedel        Lazio   Provedel            524  29-264
# ..    ... ..          ...          ...        ...     ...    ...     ...
# 537  6160  A      Vivaldo      Udinese    Vivaldo             -1       0
# 538  6242  A      Bidaoui    Frosinone    Bidaoui             -1       0
# 539  6418  A      Burnete        Lecce    Burnete             65  19-309
# 540  6419  A    Corfitzen        Lecce  Corfitzen            106  18-342
# 541  6427  A      Stewart  Salernitana    Stewart            438  23-259
#
#      birth_year  games  ...  gk_pct_goal_kicks_launched  \
# 0          1988      0  ...                        30.0
# 1          1991      0  ...                        41.5
# 2          1997      0  ...                        45.6
# 3          1997      0  ...                        25.0
# 4          1994      0  ...                        25.4
# ..          ...    ...  ...                         ...
# 537           0      0  ...                         0.0
# 538           0      0  ...                         0.0
# 539        2004      1  ...                         0.0
# 540        2004      1  ...                         0.0
# 541        2000      4  ...                         0.0
#
#      gk_goal_kick_length_avg  gk_crosses  gk_crosses_stopped  \
# 0                       30.3         149                   7
# 1                       38.7         205                   6
# 2                       42.2         194                   9
# 3                       30.1         143                   1
# 4                       30.7         152                   6
# ..                       ...         ...                 ...
# 537                      0.0           0                   0
# 538                      0.0           0                   0
# 539                      0.0           0                   0
# 540                      0.0           0                   0
# 541                      0.0           0                   0
#
#      gk_crosses_stopped_pct  gk_def_actions_outside_pen_area  \
# 0                       4.7                                8
# 1                       2.9                                3
# 2                       4.6                                6
# 3                       0.7                               12
# 4                       3.9                               10
# ..                      ...                              ...
# 537                     0.0                                0
# 538                     0.0                                0
# 539                     0.0                                0
# 540                     0.0                                0
# 541                     0.0                                0
#
#      gk_def_actions_outside_pen_area_per90  gk_avg_distance_def_actions  \
# 0                                     0.57                         12.1
# 1                                     0.21                          9.0
# 2                                     0.46                         10.2
# 3                                     1.00                         16.8
# 4                                     0.71                         13.4
# ..                                     ...                          ...
# 537                                   0.00                          0.0
# 538                                   0.00                          0.0
# 539                                   0.00                          0.0
# 540                                   0.00                          0.0
# 541                                   0.00                          0.0
#
#      vote_avg  vote_std
# 0    5.857143  0.349927
# 1    6.357143  0.349927
# 2    6.583333  0.533594
# 3    5.857143  0.225877
# 4    6.428571  0.416497
# ..        ...       ...
# 537  6.172900  0.297326
# 538  6.036372  0.496942
# 539  6.292575  0.210428
# 540  6.192570  0.614719
# 541  5.871328  0.351698
#
# [542 rows x 160 columns]

# %% [markdown]
# Print players for which the association failed.
#
# Most of them are players who didn't play a single Serie A game this season with their team. If that is the case, and there is data from their previous team, that is taken here.
#
# Others are ones for which the FBRef surname doesn't correspond to Fantacalcio one.
#
#
# For example, Cabral is Arthur for FBref.
#
# Correction is made in the name_fix code above.

# %%
exceptions = ['pellegrini', 'bastoni', 'kristensen'] # exceptions for such players that have the same surname as others (Berardi A., Luca Pellegrini)

for i in range(fc_players.shape[0]):
    if(fc_players['fb_ID'][i] == -1):
        found = False
        for j in range(players.shape[0]):
            if(fc_players['surname'][i].lower() == players['surname'][j].lower()):
                if(not(players['surname'][j].lower() in exceptions)):
                    if((fc_players['r'][i] == 'P') == (j >= keepers_ID)):
                        fc_players.loc[i, 'fb_ID']= j
                        found = True
        if(found):
            print(fc_players['name'][i] + ' from previous team stats')
        else:
            print(fc_players['name'][i] + ' not found')
# Out:
# Sepe not found
# Lamanna not found
# Sommariva not found
# Pegolo not found
# Perilli not found
# Padelli not found
# Audero not found
# Di Gennaro not found
# Pinsoglio not found
# Aresti not found
# Fiorillo not found
# Rossi F. not found
# Ravaglia F. not found
# Frattali not found
# Contini not found
# Brancolini not found
# Berardi A. not found
# Boer not found
# Bagnolini not found
# Svilar not found
# Martinelli T. not found
# Popa not found
# Stubljar not found
# Gori not found
# Borbei not found
# Okoye not found
# Mandas not found
# Kristensen not found
# Masina not found
# Tressoldi not found
# Gunter not found
# Soumaoro not found
# Dermaku not found
# Tonelli not found
# De Sciglio not found
# Capradossi not found
# Bettella not found
# Kumbulla not found
# Amey not found
# Cittadini not found
# Guarino not found
# Smajlovic not found
# N'guessan not found
# Mateus Lusuardi not found
# Kalaj not found
# Pierozzi not found
# Lindstrom not found
# Castrovilli not found
# Iling Junior not found
# Cajuste  not found
# Machin not found
# Basic not found
# Legowski not found
# Lulic K. not found
# Rog not found
# Jagiello not found
# Demme not found
# Akpa Akpro not found
# Hrustic not found
# Faticanti not found
# Belardinelli not found
# Camara E. not found
# Lipani not found
# Joselito not found
# Luvumbo not found
# Toure' E. not found
# Abraham not found
# Deulofeu not found
# Jovane not found
# Davis K. not found
# Brenner not found
# Alvarez A. not found
# Yildiz not found
# Braaf not found
# Kallon not found
# Vivaldo not found
# Bidaoui not found

# %%
fc_players
# Out:
#        id  r         name         team    surname initial  fb_ID
# 0    2428  P       Sommer        Inter     Sommer            529
# 1     133  P    Skorupski      Bologna  Skorupski            528
# 2    5876  P  Di Gregorio        Monza   Gregorio            508
# 3     572  P        Meret       Napoli      Meret            515
# 4    2814  P     Provedel        Lazio   Provedel            524
# ..    ... ..          ...          ...        ...     ...    ...
# 537  6160  A      Vivaldo      Udinese    Vivaldo             -1
# 538  6242  A      Bidaoui    Frosinone    Bidaoui             -1
# 539  6418  A      Burnete        Lecce    Burnete             65
# 540  6419  A    Corfitzen        Lecce  Corfitzen            106
# 541  6427  A      Stewart  Salernitana    Stewart            438
#
# [542 rows x 7 columns]

# %% [markdown]
# Populate players dataset with stats from FBref, for outfield players and goalkeepers

# %%
#Data for Outfield players
columns_to_copy = outfield_players.columns[4:]

fc_players[columns_to_copy] = 0

for i in range(fc_players.shape[0]):
    if(fc_players['fb_ID'][i] != -1 and fc_players['r'][i] != 'P'):
         for j in range(columns_to_copy.shape[0]):
            #fc_players[columns_to_copy[j]][i] = outfield_players[columns_to_copy[j]][fc_players['fb_ID'][i]]
            fc_players.loc[i, columns_to_copy[j]] = outfield_players.loc[fc_players['fb_ID'][i], columns_to_copy[j]]
# Out:
# /tmp/ipykernel_33524/2053436513.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy] = 0
# /tmp/ipykernel_33524/2053436513.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy] = 0
# /tmp/ipykernel_33524/2053436513.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy] = 0
# /tmp/ipykernel_33524/2053436513.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy] = 0
# /tmp/ipykernel_33524/2053436513.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy] = 0
# /tmp/ipykernel_33524/2053436513.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy] = 0
# /tmp/ipykernel_33524/2053436513.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy] = 0
# /tmp/ipykernel_33524/2053436513.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy] = 0
# /tmp/ipykernel_33524/2053436513.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy] = 0
# /tmp/ipykernel_33524/2053436513.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy] = 0
# /tmp/ipykernel_33524/2053436513.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy] = 0
# /tmp/ipykernel_33524/2053436513.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy] = 0
# /tmp/ipykernel_33524/2053436513.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy] = 0
# /tmp/ipykernel_33524/2053436513.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy] = 0
# /tmp/ipykernel_33524/2053436513.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy] = 0
# /tmp/ipykernel_33524/2053436513.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy] = 0
# /tmp/ipykernel_33524/2053436513.py:10: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '26-026' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fc_players.loc[i, columns_to_copy[j]] = outfield_players.loc[fc_players['fb_ID'][i], columns_to_copy[j]]
# /tmp/ipykernel_33524/2053436513.py:10: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.2' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fc_players.loc[i, columns_to_copy[j]] = outfield_players.loc[fc_players['fb_ID'][i], columns_to_copy[j]]
# /tmp/ipykernel_33524/2053436513.py:10: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.39' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fc_players.loc[i, columns_to_copy[j]] = outfield_players.loc[fc_players['fb_ID'][i], columns_to_copy[j]]
# /tmp/ipykernel_33524/2053436513.py:10: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.59' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fc_players.loc[i, columns_to_copy[j]] = outfield_players.loc[fc_players['fb_ID'][i], columns_to_copy[j]]
# /tmp/ipykernel_33524/2053436513.py:10: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.8' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fc_players.loc[i, columns_to_copy[j]] = outfield_players.loc[fc_players['fb_ID'][i], columns_to_copy[j]]
# /tmp/ipykernel_33524/2053436513.py:10: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.08' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fc_players.loc[i, columns_to_copy[j]] = outfield_players.loc[fc_players['fb_ID'][i], columns_to_copy[j]]
# /tmp/ipykernel_33524/2053436513.py:10: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '10.2' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fc_players.loc[i, columns_to_copy[j]] = outfield_players.loc[fc_players['fb_ID'][i], columns_to_copy[j]]
# /tmp/ipykernel_33524/2053436513.py:10: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.79' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fc_players.loc[i, columns_to_copy[j]] = outfield_players.loc[fc_players['fb_ID'][i], columns_to_copy[j]]
# /tmp/ipykernel_33524/2053436513.py:10: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.1' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fc_players.loc[i, columns_to_copy[j]] = outfield_players.loc[fc_players['fb_ID'][i], columns_to_copy[j]]
# /tmp/ipykernel_33524/2053436513.py:10: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.25' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fc_players.loc[i, columns_to_copy[j]] = outfield_players.loc[fc_players['fb_ID'][i], columns_to_copy[j]]
# /tmp/ipykernel_33524/2053436513.py:10: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.04' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fc_players.loc[i, columns_to_copy[j]] = outfield_players.loc[fc_players['fb_ID'][i], columns_to_copy[j]]
# /tmp/ipykernel_33524/2053436513.py:10: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '1.2' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fc_players.loc[i, columns_to_copy[j]] = outfield_players.loc[fc_players['fb_ID'][i], columns_to_copy[j]]
# /tmp/ipykernel_33524/2053436513.py:10: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '77.8' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fc_players.loc[i, columns_to_copy[j]] = outfield_players.loc[fc_players['fb_ID'][i], columns_to_copy[j]]
# /tmp/ipykernel_33524/2053436513.py:10: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '92.2' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fc_players.loc[i, columns_to_copy[j]] = outfield_players.loc[fc_players['fb_ID'][i], columns_to_copy[j]]
# /tmp/ipykernel_33524/2053436513.py:10: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '78.3' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fc_players.loc[i, columns_to_copy[j]] = outfield_players.loc[fc_players['fb_ID'][i], columns_to_copy[j]]
# /tmp/ipykernel_33524/2053436513.py:10: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '4.91' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fc_players.loc[i, columns_to_copy[j]] = outfield_players.loc[fc_players['fb_ID'][i], columns_to_copy[j]]
# /tmp/ipykernel_33524/2053436513.py:10: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.69' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fc_players.loc[i, columns_to_copy[j]] = outfield_players.loc[fc_players['fb_ID'][i], columns_to_copy[j]]
# /tmp/ipykernel_33524/2053436513.py:10: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '15.4' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fc_players.loc[i, columns_to_copy[j]] = outfield_players.loc[fc_players['fb_ID'][i], columns_to_copy[j]]
# /tmp/ipykernel_33524/2053436513.py:10: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '66.7' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fc_players.loc[i, columns_to_copy[j]] = outfield_players.loc[fc_players['fb_ID'][i], columns_to_copy[j]]
# /tmp/ipykernel_33524/2053436513.py:10: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '29.2' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fc_players.loc[i, columns_to_copy[j]] = outfield_players.loc[fc_players['fb_ID'][i], columns_to_copy[j]]

# %%
keeper_players.columns[4:]
# Out:
# Index(['age', 'birth_year', 'gk_games', 'gk_games_starts', 'gk_minutes',
#        'gk_goals_against', 'gk_goals_against_per90',
#        'gk_shots_on_target_against', 'gk_saves', 'gk_save_pct', 'gk_wins',
#        'gk_ties', 'gk_losses', 'gk_clean_sheets', 'gk_clean_sheets_pct',
#        'gk_pens_att', 'gk_pens_allowed', 'gk_pens_saved', 'gk_pens_missed',
#        'minutes_90s', 'gk_free_kick_goals_against',
#        'gk_corner_kick_goals_against', 'gk_own_goals_against', 'gk_psxg',
#        'gk_psnpxg_per_shot_on_target_against', 'gk_psxg_net',
#        'gk_psxg_net_per90', 'gk_passes_completed_launched',
#        'gk_passes_launched', 'gk_passes_pct_launched', 'gk_passes',
#        'gk_passes_throws', 'gk_pct_passes_launched', 'gk_passes_length_avg',
#        'gk_goal_kicks', 'gk_pct_goal_kicks_launched',
#        'gk_goal_kick_length_avg', 'gk_crosses', 'gk_crosses_stopped',
#        'gk_crosses_stopped_pct', 'gk_def_actions_outside_pen_area',
#        'gk_def_actions_outside_pen_area_per90', 'gk_avg_distance_def_actions'],
#       dtype='object')

# %%
#Data for Keepers
columns_to_copy = keeper_players.columns[4:]

fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year

delta_k = outfield_players.shape[0]

for i in range(fc_players.shape[0]):
    if(fc_players['fb_ID'][i] != -1 and fc_players['r'][i] == 'P'):
         for j in range(columns_to_copy.shape[0]):
            #fc_players[columns_to_copy[j]][i] = keeper_players[columns_to_copy[j]][fc_players['fb_ID'][i] - delta_k]
            fc_players.loc[i, columns_to_copy[j]] = keeper_players.loc[fc_players['fb_ID'][i] - delta_k, columns_to_copy[j]]
# Out:
# /tmp/ipykernel_33524/127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# /tmp/ipykernel_33524/127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# /tmp/ipykernel_33524/127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# /tmp/ipykernel_33524/127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# /tmp/ipykernel_33524/127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# /tmp/ipykernel_33524/127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# /tmp/ipykernel_33524/127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# /tmp/ipykernel_33524/127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# /tmp/ipykernel_33524/127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# /tmp/ipykernel_33524/127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# /tmp/ipykernel_33524/127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# /tmp/ipykernel_33524/127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# /tmp/ipykernel_33524/127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# /tmp/ipykernel_33524/127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# /tmp/ipykernel_33524/127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# /tmp/ipykernel_33524/127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# /tmp/ipykernel_33524/127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# /tmp/ipykernel_33524/127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# /tmp/ipykernel_33524/127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# /tmp/ipykernel_33524/127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# /tmp/ipykernel_33524/127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# /tmp/ipykernel_33524/127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# /tmp/ipykernel_33524/127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# /tmp/ipykernel_33524/127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# /tmp/ipykernel_33524/127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# /tmp/ipykernel_33524/127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# /tmp/ipykernel_33524/127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# /tmp/ipykernel_33524/127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# /tmp/ipykernel_33524/127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# /tmp/ipykernel_33524/127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# /tmp/ipykernel_33524/127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# /tmp/ipykernel_33524/127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# /tmp/ipykernel_33524/127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# /tmp/ipykernel_33524/127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# /tmp/ipykernel_33524/127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# /tmp/ipykernel_33524/127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# /tmp/ipykernel_33524/127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# /tmp/ipykernel_33524/127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# /tmp/ipykernel_33524/127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# /tmp/ipykernel_33524/127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# /tmp/ipykernel_33524/127446819.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fc_players.loc[i, columns_to_copy[j]] = keeper_players.loc[fc_players['fb_ID'][i] - delta_k, columns_to_copy[j]]
# /tmp/ipykernel_33524/127446819.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '83.8' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fc_players.loc[i, columns_to_copy[j]] = keeper_players.loc[fc_players['fb_ID'][i] - delta_k, columns_to_copy[j]]
# /tmp/ipykernel_33524/127446819.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '64.3' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fc_players.loc[i, columns_to_copy[j]] = keeper_players.loc[fc_players['fb_ID'][i] - delta_k, columns_to_copy[j]]
# /tmp/ipykernel_33524/127446819.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '8.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fc_players.loc[i, columns_to_copy[j]] = keeper_players.loc[fc_players['fb_ID'][i] - delta_k, columns_to_copy[j]]
# /tmp/ipykernel_33524/127446819.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.2' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fc_players.loc[i, columns_to_copy[j]] = keeper_players.loc[fc_players['fb_ID'][i] - delta_k, columns_to_copy[j]]
# /tmp/ipykernel_33524/127446819.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '1.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fc_players.loc[i, columns_to_copy[j]] = keeper_players.loc[fc_players['fb_ID'][i] - delta_k, columns_to_copy[j]]
# /tmp/ipykernel_33524/127446819.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.11' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fc_players.loc[i, columns_to_copy[j]] = keeper_players.loc[fc_players['fb_ID'][i] - delta_k, columns_to_copy[j]]
# /tmp/ipykernel_33524/127446819.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '49.2' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fc_players.loc[i, columns_to_copy[j]] = keeper_players.loc[fc_players['fb_ID'][i] - delta_k, columns_to_copy[j]]
# /tmp/ipykernel_33524/127446819.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '24.7' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fc_players.loc[i, columns_to_copy[j]] = keeper_players.loc[fc_players['fb_ID'][i] - delta_k, columns_to_copy[j]]
# /tmp/ipykernel_33524/127446819.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '28.3' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fc_players.loc[i, columns_to_copy[j]] = keeper_players.loc[fc_players['fb_ID'][i] - delta_k, columns_to_copy[j]]
# /tmp/ipykernel_33524/127446819.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '30.3' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fc_players.loc[i, columns_to_copy[j]] = keeper_players.loc[fc_players['fb_ID'][i] - delta_k, columns_to_copy[j]]
# /tmp/ipykernel_33524/127446819.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '4.7' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fc_players.loc[i, columns_to_copy[j]] = keeper_players.loc[fc_players['fb_ID'][i] - delta_k, columns_to_copy[j]]
# /tmp/ipykernel_33524/127446819.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.57' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fc_players.loc[i, columns_to_copy[j]] = keeper_players.loc[fc_players['fb_ID'][i] - delta_k, columns_to_copy[j]]
# /tmp/ipykernel_33524/127446819.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '12.1' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fc_players.loc[i, columns_to_copy[j]] = keeper_players.loc[fc_players['fb_ID'][i] - delta_k, columns_to_copy[j]]
# /tmp/ipykernel_33524/127446819.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '41.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fc_players.loc[i, columns_to_copy[j]] = keeper_players.loc[fc_players['fb_ID'][i] - delta_k, columns_to_copy[j]]

# %%
fc_players
# Out:
#        id  r         name         team    surname initial  fb_ID     age  \
# 0    2428  P       Sommer        Inter     Sommer            529  34-354
# 1     133  P    Skorupski      Bologna  Skorupski            528  32-215
# 2    5876  P  Di Gregorio        Monza   Gregorio            508  26-132
# 3     572  P        Meret       Napoli      Meret            515  26-259
# 4    2814  P     Provedel        Lazio   Provedel            524  29-264
# ..    ... ..          ...          ...        ...     ...    ...     ...
# 537  6160  A      Vivaldo      Udinese    Vivaldo             -1       0
# 538  6242  A      Bidaoui    Frosinone    Bidaoui             -1       0
# 539  6418  A      Burnete        Lecce    Burnete             65  19-309
# 540  6419  A    Corfitzen        Lecce  Corfitzen            106  18-342
# 541  6427  A      Stewart  Salernitana    Stewart            438  23-259
#
#      birth_year  games  ...  gk_passes_length_avg  gk_goal_kicks  \
# 0          1988      0  ...                  28.3             80
# 1          1991      0  ...                  30.2             82
# 2          1997      0  ...                  29.3             90
# 3          1997      0  ...                  27.3             56
# 4          1994      0  ...                  28.4             63
# ..          ...    ...  ...                   ...            ...
# 537           0      0  ...                   0.0              0
# 538           0      0  ...                   0.0              0
# 539        2004      1  ...                   0.0              0
# 540        2004      1  ...                   0.0              0
# 541        2000      4  ...                   0.0              0
#
#      gk_pct_goal_kicks_launched  gk_goal_kick_length_avg  gk_crosses  \
# 0                          30.0                     30.3         149
# 1                          41.5                     38.7         205
# 2                          45.6                     42.2         194
# 3                          25.0                     30.1         143
# 4                          25.4                     30.7         152
# ..                          ...                      ...         ...
# 537                         0.0                      0.0           0
# 538                         0.0                      0.0           0
# 539                         0.0                      0.0           0
# 540                         0.0                      0.0           0
# 541                         0.0                      0.0           0
#
#      gk_crosses_stopped  gk_crosses_stopped_pct  \
# 0                     7                     4.7
# 1                     6                     2.9
# 2                     9                     4.6
# 3                     1                     0.7
# 4                     6                     3.9
# ..                  ...                     ...
# 537                   0                     0.0
# 538                   0                     0.0
# 539                   0                     0.0
# 540                   0                     0.0
# 541                   0                     0.0
#
#      gk_def_actions_outside_pen_area  gk_def_actions_outside_pen_area_per90  \
# 0                                  8                                   0.57
# 1                                  3                                   0.21
# 2                                  6                                   0.46
# 3                                 12                                   1.00
# 4                                 10                                   0.71
# ..                               ...                                    ...
# 537                                0                                   0.00
# 538                                0                                   0.00
# 539                                0                                   0.00
# 540                                0                                   0.00
# 541                                0                                   0.00
#
#      gk_avg_distance_def_actions
# 0                           12.1
# 1                            9.0
# 2                           10.2
# 3                           16.8
# 4                           13.4
# ..                           ...
# 537                          0.0
# 538                          0.0
# 539                          0.0
# 540                          0.0
# 541                          0.0
#
# [542 rows x 158 columns]

# %% [markdown]
# Load votes database, to add data to players database (mean vote and its standard deviation)

# %%
import numpy as np

votes = pd.read_excel('mid_outputs/players_votes.xlsx', index_col = 0)

# %% [markdown]
# Compute the average Serie A Goal Keeper mean vote and vote std

# %%
min_votes = 3 # TO BE UPDATED WHEN SERIE A HAS MORE CALENDAR WEEKS PLAYED

perf_df_P = pd.DataFrame(columns = ['vote_avg', 'vote_std'])

for i in range(fc_players.shape[0]): 
    if(fc_players.loc[i]['r'] == 'P'):
        v = np.array([])
        for j in range(votes.shape[0]):
            if(fc_players['name'][i] == votes['player'][j]):
                v = np.append(v, votes['vote'][j])

        if(v.shape[0] >= min_votes - 1):
            row_df = pd.DataFrame(data = [[np.mean(v), np.std(v)]], columns = perf_df_P.columns)
            perf_df_P = pd.concat([perf_df_P, row_df], ignore_index = True)


print(perf_df_P.mean())

perf_df_P
# Out:
# /tmp/ipykernel_33524/3315699811.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   perf_df_P = pd.concat([perf_df_P, row_df], ignore_index = True)
# vote_avg    6.102000
# vote_std    0.378953
# dtype: float64
#     vote_avg  vote_std
# 0   5.857143  0.349927
# 1   6.357143  0.349927
# 2   6.583333  0.533594
# 3   5.857143  0.225877
# 4   6.428571  0.416497
# 5   6.200000  0.678233
# 6   6.000000  1.048809
# 7   6.357143  0.440315
# 8   6.000000  0.267261
# 9   6.000000  0.000000
# 10  6.428571  0.319438
# 11  5.857143  0.440315
# 12  6.416667  0.671855
# 13  6.100000  0.374166
# 14  6.300000  0.244949
# 15  6.000000  0.000000
# 16  5.714286  0.795395
# 17  5.571429  0.416497
# 18  5.857143  0.225877
# 19  6.214286  0.524891
# 20  6.250000  0.250000
# 21  6.200000  0.400000
# 22  6.000000  0.000000
# 23  6.250000  0.250000
# 24  5.750000  0.250000

# %% [markdown]
# Add to players data their mean vote (and its standard deviation).
#
# For players who don't have a minimum amount of games, more data to reach this value is computed, according to the average Serie A player vote (and std). For goalkeepers, this values are different.

# %%
min_votes = 3 # TO BE UPDATED WHEN SERIE A HAS MORE CALENDAR WEEKS PLAYED

#outfield players
mean_def = 6
std_def = 0.58

#goalkeepers
mean_def_P = 6.22
std_def_P = 0.43


perf_df = pd.DataFrame(columns = ['vote_avg', 'vote_std'])

for i in range(fc_players.shape[0]):
    v = np.array([])
    for j in range(votes.shape[0]):
        if(fc_players['name'][i] == votes['player'][j]):
            v = np.append(v, votes['vote'][j])
    
    mean_def_i = mean_def
    std_def_i = std_def
    
    if(fc_players['r'][i] == 'P'):
        mean_def_i = mean_def_P
        std_def_i = std_def_P
        
    if(v.shape[0] < min_votes):
         for k in range(min_votes - v.shape[0]):
            v = np.append( v, np.random.normal(mean_def_i, std_def_i) )
    
    row_df = pd.DataFrame(data = [[np.mean(v), np.std(v)]], columns = perf_df.columns)
    perf_df = pd.concat([perf_df, row_df], ignore_index = True)
    
perf_df
# Out:
# /tmp/ipykernel_33524/1006814721.py:32: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   perf_df = pd.concat([perf_df, row_df], ignore_index = True)
#      vote_avg  vote_std
# 0    5.857143  0.349927
# 1    6.357143  0.349927
# 2    6.583333  0.533594
# 3    5.857143  0.225877
# 4    6.428571  0.416497
# ..        ...       ...
# 537  6.172900  0.297326
# 538  6.036372  0.496942
# 539  6.292575  0.210428
# 540  6.192570  0.614719
# 541  5.871328  0.351698
#
# [542 rows x 2 columns]

# %%
fc_players = pd.concat([fc_players, perf_df], axis = 1)

fc_players
# Out:
#        id  r         name         team    surname initial  fb_ID     age  \
# 0    2428  P       Sommer        Inter     Sommer            529  34-354
# 1     133  P    Skorupski      Bologna  Skorupski            528  32-215
# 2    5876  P  Di Gregorio        Monza   Gregorio            508  26-132
# 3     572  P        Meret       Napoli      Meret            515  26-259
# 4    2814  P     Provedel        Lazio   Provedel            524  29-264
# ..    ... ..          ...          ...        ...     ...    ...     ...
# 537  6160  A      Vivaldo      Udinese    Vivaldo             -1       0
# 538  6242  A      Bidaoui    Frosinone    Bidaoui             -1       0
# 539  6418  A      Burnete        Lecce    Burnete             65  19-309
# 540  6419  A    Corfitzen        Lecce  Corfitzen            106  18-342
# 541  6427  A      Stewart  Salernitana    Stewart            438  23-259
#
#      birth_year  games  ...  gk_pct_goal_kicks_launched  \
# 0          1988      0  ...                        30.0
# 1          1991      0  ...                        41.5
# 2          1997      0  ...                        45.6
# 3          1997      0  ...                        25.0
# 4          1994      0  ...                        25.4
# ..          ...    ...  ...                         ...
# 537           0      0  ...                         0.0
# 538           0      0  ...                         0.0
# 539        2004      1  ...                         0.0
# 540        2004      1  ...                         0.0
# 541        2000      4  ...                         0.0
#
#      gk_goal_kick_length_avg  gk_crosses  gk_crosses_stopped  \
# 0                       30.3         149                   7
# 1                       38.7         205                   6
# 2                       42.2         194                   9
# 3                       30.1         143                   1
# 4                       30.7         152                   6
# ..                       ...         ...                 ...
# 537                      0.0           0                   0
# 538                      0.0           0                   0
# 539                      0.0           0                   0
# 540                      0.0           0                   0
# 541                      0.0           0                   0
#
#      gk_crosses_stopped_pct  gk_def_actions_outside_pen_area  \
# 0                       4.7                                8
# 1                       2.9                                3
# 2                       4.6                                6
# 3                       0.7                               12
# 4                       3.9                               10
# ..                      ...                              ...
# 537                     0.0                                0
# 538                     0.0                                0
# 539                     0.0                                0
# 540                     0.0                                0
# 541                     0.0                                0
#
#      gk_def_actions_outside_pen_area_per90  gk_avg_distance_def_actions  \
# 0                                     0.57                         12.1
# 1                                     0.21                          9.0
# 2                                     0.46                         10.2
# 3                                     1.00                         16.8
# 4                                     0.71                         13.4
# ..                                     ...                          ...
# 537                                   0.00                          0.0
# 538                                   0.00                          0.0
# 539                                   0.00                          0.0
# 540                                   0.00                          0.0
# 541                                   0.00                          0.0
#
#      vote_avg  vote_std
# 0    5.857143  0.349927
# 1    6.357143  0.349927
# 2    6.583333  0.533594
# 3    5.857143  0.225877
# 4    6.428571  0.416497
# ..        ...       ...
# 537  6.172900  0.297326
# 538  6.036372  0.496942
# 539  6.292575  0.210428
# 540  6.192570  0.614719
# 541  5.871328  0.351698
#
# [542 rows x 160 columns]

# %%
GK_GAMES_COLUMN = 118

fc_players.columns[GK_GAMES_COLUMN]

# check it if is 'gk_games'
# Out:
# 'gk_games'

# %% [markdown]
# For goalkeepers who didn't play a miminum amount of games, data is weightly averaged with one of the main goalkeeper of their same team.

# %%
min_gk_games = 3 # TO BE UPDATED WHEN SERIE A HAS MORE CALENDAR WEEKS PLAYED

fc_players_newgk = fc_players.copy()

columns_to_avg = fc_players.columns[GK_GAMES_COLUMN:] # from gk_games to end

for i in range(fc_players.shape[0]):
    if(fc_players['r'][i] == 'P'):
        if(fc_players['gk_games'][i] < min_gk_games):
            for j in range(fc_players.shape[0]):
                if(fc_players['team'][i] == fc_players['team'][j] and fc_players['gk_games'][j] >= min_gk_games):
                    break
                    
            weight = 1 - (min_gk_games - fc_players['gk_games'][i]) / min_gk_games
            
            fc_players_newgk.at[i, columns_to_avg] = fc_players.loc[i][columns_to_avg] * weight + (1 - weight) * fc_players.loc[j][columns_to_avg]
            
            print(fc_players['name'][i] + ', ' + str(weight))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/.pyenv/versions/3.12.0/envs/fantapredict/lib/python3.12/site-packages/pandas/core/indexes/base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:158, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: 'Index(['gk_games', 'gk_games_starts', 'gk_minutes', 'gk_goals_against',
#        'gk_goals_against_per90', 'gk_shots_on_target_against', 'gk_saves',
#        'gk_save_pct', 'gk_wins', 'gk_ties', 'gk_losses', 'gk_clean_sheets',
#        'gk_clean_sheets_pct', 'gk_pens_att', 'gk_pens_allowed',
#        'gk_pens_saved', 'gk_pens_missed', 'gk_free_kick_goals_against',
#        'gk_corner_kick_goals_against', 'gk_own_goals_against', 'gk_psxg',
#        'gk_psnpxg_per_shot_on_target_against', 'gk_psxg_net',
#        'gk_psxg_net_per90', 'gk_passes_completed_launched',
#        'gk_passes_launched', 'gk_passes_pct_launched', 'gk_passes',
#        'gk_passes_throws', 'gk_pct_passes_launched', 'gk_passes_length_avg',
#        'gk_goal_kicks', 'gk_pct_goal_kicks_launched',
#        'gk_goal_kick_length_avg', 'gk_crosses', 'gk_crosses_stopped',
#        'gk_crosses_stopped_pct', 'gk_def_actions_outside_pen_area',
#        'gk_def_actions_outside_pen_area_per90', 'gk_avg_distance_def_actions',
#        'vote_avg', 'vote_std'],
#       dtype='object')' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# File ~/.pyenv/versions/3.12.0/envs/fantapredict/lib/python3.12/site-packages/pandas/core/frame.py:4337, in DataFrame._set_value(self, index, col, value, takeable)
#    4336 else:
# -> 4337     icol = self.columns.get_loc(col)
#    4338     iindex = self.index.get_loc(index)
#
# File ~/.pyenv/versions/3.12.0/envs/fantapredict/lib/python3.12/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key)
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
# -> 3802     self._check_indexing_error(key)
#    3803     raise
#
# File ~/.pyenv/versions/3.12.0/envs/fantapredict/lib/python3.12/site-packages/pandas/core/indexes/base.py:5974, in Index._check_indexing_error(self, key)
#    5971 if not is_scalar(key):
#    5972     # if key is not a scalar, directly raise an error (the code below
#    5973     # would convert to numpy arrays and raise later any way) - GH29926
# -> 5974     raise InvalidIndexError(key)
#
# InvalidIndexError: Index(['gk_games', 'gk_games_starts', 'gk_minutes', 'gk_goals_against',
#        'gk_goals_against_per90', 'gk_shots_on_target_against', 'gk_saves',
#        'gk_save_pct', 'gk_wins', 'gk_ties', 'gk_losses', 'gk_clean_sheets',
#        'gk_clean_sheets_pct', 'gk_pens_att', 'gk_pens_allowed',
#        'gk_pens_saved', 'gk_pens_missed', 'gk_free_kick_goals_against',
#        'gk_corner_kick_goals_against', 'gk_own_goals_against', 'gk_psxg',
#        'gk_psnpxg_per_shot_on_target_against', 'gk_psxg_net',
#        'gk_psxg_net_per90', 'gk_passes_completed_launched',
#        'gk_passes_launched', 'gk_passes_pct_launched', 'gk_passes',
#        'gk_passes_throws', 'gk_pct_passes_launched', 'gk_passes_length_avg',
#        'gk_goal_kicks', 'gk_pct_goal_kicks_launched',
#        'gk_goal_kick_length_avg', 'gk_crosses', 'gk_crosses_stopped',
#        'gk_crosses_stopped_pct', 'gk_def_actions_outside_pen_area',
#        'gk_def_actions_outside_pen_area_per90', 'gk_avg_distance_def_actions',
#        'vote_avg', 'vote_std'],
#       dtype='object')
#
# The above exception was the direct cause of the following exception:
#
# InvalidIndexError                         Traceback (most recent call last)
# /tmp/ipykernel_33524/925074866.py in ?()
#      12                     break
#      13
#      14             weight = 1 - (min_gk_games - fc_players['gk_games'][i]) / min_gk_games
#      15
# ---> 16             fc_players_newgk.at[i, columns_to_avg] = fc_players.loc[i][columns_to_avg] * weight + (1 - weight) * fc_players.loc[j][columns_to_avg]
#      17
#      18             print(fc_players['name'][i] + ', ' + str(weight))
#      19
#
# ~/.pyenv/versions/3.12.0/envs/fantapredict/lib/python3.12/site-packages/pandas/core/indexing.py in ?(self, key, value)
#    2495
#    2496             self.obj.loc[key] = value
#    2497             return
#    2498
# -> 2499         return super().__setitem__(key, value)
#
# ~/.pyenv/versions/3.12.0/envs/fantapredict/lib/python3.12/site-packages/pandas/core/indexing.py in ?(self, key, value)
#    2451         key = list(self._convert_key(key))
#    2452         if len(key) != self.ndim:
#    2453             raise ValueError("Not enough indexers for scalar access (setting)!")
#    2454
# -> 2455         self.obj._set_value(*key, value=value, takeable=self._takeable)
#
# ~/.pyenv/versions/3.12.0/envs/fantapredict/lib/python3.12/site-packages/pandas/core/frame.py in ?(self, index, col, value, takeable)
#    4353
#    4354         except InvalidIndexError as ii_err:
#    4355             # GH48729: Seems like you are trying to assign a value to a
#    4356             # row when only scalar options are permitted
# -> 4357             raise InvalidIndexError(
#    4358                 f"You can only assign a scalar value not a {type(value)}"
#    4359             ) from ii_err
#
# InvalidIndexError: You can only assign a scalar value not a <class 'pandas.core.series.Series'>

# %%
fc_players = fc_players_newgk

fc_players
# Out:
#        id  r         name         team    surname initial  fb_ID     age  \
# 0    2428  P       Sommer        Inter     Sommer            529  34-354
# 1     133  P    Skorupski      Bologna  Skorupski            528  32-215
# 2    5876  P  Di Gregorio        Monza   Gregorio            508  26-132
# 3     572  P        Meret       Napoli      Meret            515  26-259
# 4    2814  P     Provedel        Lazio   Provedel            524  29-264
# ..    ... ..          ...          ...        ...     ...    ...     ...
# 537  6160  A      Vivaldo      Udinese    Vivaldo             -1       0
# 538  6242  A      Bidaoui    Frosinone    Bidaoui             -1       0
# 539  6418  A      Burnete        Lecce    Burnete             65  19-309
# 540  6419  A    Corfitzen        Lecce  Corfitzen            106  18-342
# 541  6427  A      Stewart  Salernitana    Stewart            438  23-259
#
#      birth_year  games  ...  gk_pct_goal_kicks_launched  \
# 0          1988      0  ...                        30.0
# 1          1991      0  ...                        41.5
# 2          1997      0  ...                        45.6
# 3          1997      0  ...                        25.0
# 4          1994      0  ...                        25.4
# ..          ...    ...  ...                         ...
# 537           0      0  ...                         0.0
# 538           0      0  ...                         0.0
# 539        2004      1  ...                         0.0
# 540        2004      1  ...                         0.0
# 541        2000      4  ...                         0.0
#
#      gk_goal_kick_length_avg  gk_crosses  gk_crosses_stopped  \
# 0                       30.3         149                   7
# 1                       38.7         205                   6
# 2                       42.2         194                   9
# 3                       30.1         143                   1
# 4                       30.7         152                   6
# ..                       ...         ...                 ...
# 537                      0.0           0                   0
# 538                      0.0           0                   0
# 539                      0.0           0                   0
# 540                      0.0           0                   0
# 541                      0.0           0                   0
#
#      gk_crosses_stopped_pct  gk_def_actions_outside_pen_area  \
# 0                       4.7                                8
# 1                       2.9                                3
# 2                       4.6                                6
# 3                       0.7                               12
# 4                       3.9                               10
# ..                      ...                              ...
# 537                     0.0                                0
# 538                     0.0                                0
# 539                     0.0                                0
# 540                     0.0                                0
# 541                     0.0                                0
#
#      gk_def_actions_outside_pen_area_per90  gk_avg_distance_def_actions  \
# 0                                     0.57                         12.1
# 1                                     0.21                          9.0
# 2                                     0.46                         10.2
# 3                                     1.00                         16.8
# 4                                     0.71                         13.4
# ..                                     ...                          ...
# 537                                   0.00                          0.0
# 538                                   0.00                          0.0
# 539                                   0.00                          0.0
# 540                                   0.00                          0.0
# 541                                   0.00                          0.0
#
#      vote_avg  vote_std
# 0    5.857143  0.349927
# 1    6.357143  0.349927
# 2    6.583333  0.533594
# 3    5.857143  0.225877
# 4    6.428571  0.416497
# ..        ...       ...
# 537  6.172900  0.297326
# 538  6.036372  0.496942
# 539  6.292575  0.210428
# 540  6.192570  0.614719
# 541  5.871328  0.351698
#
# [542 rows x 160 columns]

# %% [markdown]
# Save to file.

# %%
fc_players.to_excel('mid_outputs/players_stats.xlsx')
